# %%
import pandas as pd
import numpy as np

# %%
data1516 = pd.read_excel('Data Sources/accdrilldwn1516_4Pandas.xlsx')
data1617 = pd.read_excel('Data Sources/accdrilldwn1617_4Pandas.xlsx')
data1718 = pd.read_excel('Data Sources/data-report1718.xlsx', sheet_name="Assess-Ind Data Set")
data1819 = pd.read_excel('Data Sources/data-report1819.xlsx', sheet_name="Assess-Ind Data Set")

# %%
data1617.columns
# Out:
# Index(['District Name', 'School Code', 'School Name', 'SBE District',
#        'Subject', 'Standard (CCR - Level 4 & 5, GLP - Level 3 & Above)',
#        'All Students', 'Female', ' Male', 'American Indian', 'Asian', 'Black',
#        'Hispanic', 'Two or More Races', ' White', 'EDS', 'LEP', 'SWD', 'AIG',
#        'All Students.1', 'Female.1', ' Male.1', 'American Indian.1', 'Asian.1',
#        'Black.1', 'Hispanic.1', 'Two or More Races.1', ' White.1', 'EDS.1',
#        'LEP.1', 'SWD.1', 'AIG.1', 'Year'],
#       dtype='object')

# %%
total_df = pd.DataFrame

# %%
data1617['Year'] = "'16-'17"
total_df = data1617
data1516['Year'] = "'15-'16"
total_df = total_df.append(data1516)

# %%
total_df
# Out:
#                  District Name School Code                 School Name  \
# 0      State of North Carolina          NC     State of North Carolina
# 1      State of North Carolina          NC     State of North Carolina
# 2      State of North Carolina          NC     State of North Carolina
# 3      State of North Carolina          NC     State of North Carolina
# 4      State of North Carolina          NC     State of North Carolina
# ...                        ...         ...                         ...
# 84944          Charter Schools      98B000  Wilson Preparatory Academy
# 84945          Charter Schools      98B000  Wilson Preparatory Academy
# 84946          Charter Schools      98B000  Wilson Preparatory Academy
# 84947          Charter Schools      98B000  Wilson Preparatory Academy
# 84948          Charter Schools      98B000  Wilson Preparatory Academy
#
#                SBE District                 Subject  \
# 0                       NaN    All EOG/EOC Subjects
# 1                       NaN        All EOC Subjects
# 2                       NaN             EOC Biology
# 3                       NaN           EOC English 2
# 4                       NaN              EOC Math I
# ...                     ...                     ...
# 84944  North Central Region        EOG Math Grade 7
# 84945  North Central Region        EOG Math Grade 8
# 84946  North Central Region  EOG Science Grades 5&8
# 84947  North Central Region     EOG Science Grade 5
# 84948  North Central Region     EOG Science Grade 8
#
#       Standard (CCR - Level 4 & 5, GLP - Level 3 & Above) All Students Female  \
# 0                               College and Career Ready          49.2   51.0
# 1                               College and Career Ready          50.9   54.0
# 2                               College and Career Ready          47.5   48.5
# 3                               College and Career Ready          50.1   56.0
# 4                               College and Career Ready          54.1   56.6
# ...                                                  ...           ...    ...
# 84944                             Grade Level Proficient          60.5   65.0
# 84945                             Grade Level Proficient          30.6   50.0
# 84946                             Grade Level Proficient          86.9   88.2
# 84947                             Grade Level Proficient          87.5   90.0
# 84948                             Grade Level Proficient          86.1   85.7
#
#        Male American Indian  ... Asian.1 Black.1 Hispanic.1  \
# 0      47.6            33.4  ...   64469  509546     342683
# 1      48.0            33.6  ...   12697   96147      57565
# 2      46.5            33.0  ...    3592   29523      16915
# 3      44.4            30.9  ...    3542   31119      17970
# 4      51.8            36.5  ...    5563   35505      22680
# ...     ...             ...  ...     ...     ...        ...
# 84944  56.5               *  ...     <10      15        <10
# 84945  18.2               *  ...     <10      18        <10
# 84946  86.0               *  ...     <10      34        <10
# 84947  85.7               *  ...     <10      16        <10
# 84948  86.4               *  ...     <10      18        <10
#
#       Two or More Races.1  White.1   EDS.1  LEP.1   SWD.1   AIG.1     Year
# 0                   83948   998834  995415  95195  255617  305064  '16-'17
# 1                   14718   200303  170107  13634   42229   76138  '16-'17
# 2                    4258    58641   50089   3627   12962   19977  '16-'17
# 3                    4508    61362   54188   4153   13851   20321  '16-'17
# 4                    5952    80300   65830   5854   15416   35840  '16-'17
# ...                   ...      ...     ...    ...     ...     ...      ...
# 84944                 <10       24      11    <10     <10     <10  '15-'16
# 84945                 <10       15     <10    <10     <10     <10  '15-'16
# 84946                 <10       38      26    <10     <10     <10  '15-'16
# 84947                 <10       23      17    <10     <10     <10  '15-'16
# 84948                 <10       15     <10    <10     <10     <10  '15-'16
#
# [170715 rows x 33 columns]

# %%
subgroup_dict = {
    "ALL":"All Students",
    "FEM":"Female", 
    "MALE":"Male",
    "AMIN":"American Indian",
    "ASIA":"Asian",
    "BLCK":"Black",
    "HISP":"Hispanic",
    "MULT":"Two or More Races",
    "WHTE":"White",
    "EDS":"Economically Disadvantaged Student",
    "ELS":"English Learners",
    "SWD":"Students with Disabilities",
    "AIG":"Academically or Intellectually Gifted",
    "HMS":"Homeless",
    "FCS":"Foster Care",
    "MIL":"Military Connected"
}
column_match = {
    "school_code":"School Code",
    "school_name":"School Name",
    "lea_name":"District Name",
    "subject":"Subject",
    "reporting_year":"Year",
    "subgroup":"Subgroup"
}

# %%
df = pd.DataFrame(data1718)

# Renames the columns in the column match variable
df = df.rename(columns=column_match)

# Drops the Year and adds in a hard coded variable for what year to match other data
df = df.drop('Year', axis=1)
df['Year'] = "'17-'18"

df['Subgroup'].replace(subgroup_dict, inplace=True)

df = df.pivot(index=["District Name", "School Code", "School Name", "Year", "Subject"], columns="Subgroup", values="total_pct")
df = df.reset_index()
df
# Out:
# Subgroup                District Name School Code  \
# 0         Alamance-Burlington Schools         010
# 1         Alamance-Burlington Schools         010
# 2         Alamance-Burlington Schools         010
# 3         Alamance-Burlington Schools         010
# 4         Alamance-Burlington Schools         010
# ...                               ...         ...
# 51574           Yancey County Schools      995336
# 51575           Yancey County Schools      995336
# 51576           Yancey County Schools      995336
# 51577           Yancey County Schools      995336
# 51578           Yancey County Schools      995336
#
# Subgroup                  School Name     Year Subject  \
# 0         Alamance-Burlington Schools  '17-'18     ACT
# 1         Alamance-Burlington Schools  '17-'18   ACT4B
# 2         Alamance-Burlington Schools  '17-'18   ACT5B
# 3         Alamance-Burlington Schools  '17-'18  ACTALL
# 4         Alamance-Burlington Schools  '17-'18   ACTEN
# ...                               ...      ...     ...
# 51574            South Toe Elementary  '17-'18    RD04
# 51575            South Toe Elementary  '17-'18    RD05
# 51576            South Toe Elementary  '17-'18    RDGS
# 51577            South Toe Elementary  '17-'18    SC05
# 51578            South Toe Elementary  '17-'18    SCGS
#
# Subgroup Academically or Intellectually Gifted All Students American Indian  \
# 0                                         93.3         49.1             NaN
# 1                                         45.0         12.0             NaN
# 2                                         27.7          7.4             NaN
# 3                                         63.2         23.7            17.1
# 4                                         80.5         32.5             NaN
# ...                                        ...          ...             ...
# 51574                                      NaN          NaN             NaN
# 51575                                      NaN          NaN             NaN
# 51576                                      NaN          NaN             NaN
# 51577                                      NaN          NaN             NaN
# 51578                                      NaN          NaN             NaN
#
# Subgroup Asian Black  ... English Learners Female Foster Care Hispanic  \
# 0         62.1  33.2  ...             10.9   53.7         NaN     37.3
# 1         27.6    <5  ...               <5   11.7         NaN       <5
# 2         14.3    <5  ...               <5    8.3         NaN       <5
# 3         40.3  10.5  ...               <5   24.9          <5     14.6
# 4         55.2  15.8  ...              5.5   34.4         NaN     20.1
# ...        ...   ...  ...              ...    ...         ...      ...
# 51574      NaN   NaN  ...              NaN    NaN         NaN      NaN
# 51575      NaN   NaN  ...              NaN    NaN         NaN      NaN
# 51576      NaN   NaN  ...              NaN    NaN         NaN      NaN
# 51577      NaN   NaN  ...              NaN    NaN         NaN      NaN
# 51578      NaN   NaN  ...              NaN    NaN         NaN      NaN
#
# Subgroup Homeless  Male Military Connected Students with Disabilities  \
# 0            14.3  44.7                NaN                        8.6
# 1             7.1  12.3                NaN                         <5
# 2              <5   6.5                NaN                         <5
# 3             8.8  22.4               20.0                         <5
# 4             7.1  30.7                NaN                         <5
# ...           ...   ...                ...                        ...
# 51574         NaN   NaN                NaN                        NaN
# 51575         NaN   NaN                NaN                        NaN
# 51576         NaN   NaN                NaN                        NaN
# 51577         NaN   NaN                NaN                        NaN
# 51578         NaN   NaN                NaN                        NaN
#
# Subgroup Two or More Races White
# 0                     38.7  62.1
# 1                     14.5  18.1
# 2                      8.2  12.1
# 3                     19.4  33.4
# 4                     22.6  45.6
# ...                    ...   ...
# 51574                  NaN   NaN
# 51575                  NaN   NaN
# 51576                  NaN   NaN
# 51577                  NaN   NaN
# 51578                  NaN   NaN
#
# [51579 rows x 21 columns]

# %%
total_df = total_df.append(df)

# %%
total_df['Subject'].value_counts()
# Out:
# All EOG/EOC Subjects      10682
# All EOG Subjects           8670
# EOG Math Grades 3-8        8648
# EOG Reading Grades 3-8     8646
# EOG Science Grades 5&8     8166
#                           ...
# M1SEP                      1320
# WK                         1037
# ACT WorkKeys               1034
# M3                          730
# M3A                         609
# Name: Subject, Length: 89, dtype: int64

# %%
total_df.to_csv("Data Sources/TEST_15-19.csv")
