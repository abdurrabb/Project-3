# %%
import pandas as pd

# %%
alex_final = pd.read_excel('data-report2019_october_final High School.xlsx', 'Assess-Ind Data Set')

# %%
target_schools = pd.read_csv('final_school_list.csv')
target_schools = target_schools[['school_name', 'school_id']].rename(columns={'school_id': 'school_code'}).astype({'school_code': str})
ids = target_schools['school_code']

# %%
a_filtered = alex_final.loc[alex_final['school_code'].isin(ids)].copy()
target_columns = a_filtered[['reporting_year','school_code', 'grade_span', 'title_1', 'subgroup', 'subject', 'den', 'total_pct']].astype({'school_code': str}).copy()

# %%
school_names = target_columns.merge(target_schools, on = 'school_code', how='left')

# %%
final_2019 = school_names.replace(regex =r'^[<>]', value='').replace(regex =r'^[*]', value='0')
final_2019
# Out:
#       reporting_year school_code grade_span title_1 subgroup subject  den  \
# 0               2019      600302      09-12     NaN      ALL     ACT  747
# 1               2019      600302      09-12     NaN      FEM     ACT  394
# 2               2019      600302      09-12     NaN     MALE     ACT  353
# 3               2019      600302      09-12     NaN     ASIA     ACT  149
# 4               2019      600302      09-12     NaN     BLCK     ACT   90
# ...              ...         ...        ...     ...      ...     ...  ...
# 7975            2019      600594      11-13     NaN     NSWD     MCR   93
# 7976            2019      600594      11-13     NaN      ALL   PCALL   17
# 7977            2019      600594      11-13     NaN      FEM   PCALL   11
# 7978            2019      600594      11-13     NaN     NEDS   PCALL   15
# 7979            2019      600594      11-13     NaN     NSWD   PCALL   16
#
#      total_pct                     school_name
# 0         85.1         Ardrey Kell High School
# 1         84.8         Ardrey Kell High School
# 2         85.6         Ardrey Kell High School
# 3           95         Ardrey Kell High School
# 4         65.6         Ardrey Kell High School
# ...        ...                             ...
# 7975        95  Merancas Middle College @ CPCC
# 7976       NaN  Merancas Middle College @ CPCC
# 7977       NaN  Merancas Middle College @ CPCC
# 7978       NaN  Merancas Middle College @ CPCC
# 7979       NaN  Merancas Middle College @ CPCC
#
# [7980 rows x 9 columns]

# %%
eight = pd.read_excel('data-report2018.xlsx', sheet_name = 'Assess-Ind Data Set')

# %%
a_filtered_18 = eight.loc[eight['school_code'].isin(ids)].copy()
target_columns_18 = a_filtered_18[['reporting_year','school_code', 'grade_span', 'title_1', 'subgroup', 'subject', 'den', 'total_pct']].astype({'school_code': str}).copy()
school_names_18 = target_columns_18.merge(target_schools, on = 'school_code', how='left')
final_2018 = school_names_18.replace(regex =r'^[<>]', value='').replace(regex =r'^[*]', value='0')
final_2018
# Out:
#       reporting_year school_code grade_span title_1 subgroup subject  den  \
# 0               2018      600302      09-12     NaN      ALL     ACT  771
# 1               2018      600302      09-12     NaN      FEM     ACT  355
# 2               2018      600302      09-12     NaN     MALE     ACT  416
# 3               2018      600302      09-12     NaN     ASIA     ACT  145
# 4               2018      600302      09-12     NaN     BLCK     ACT   86
# ...              ...         ...        ...     ...      ...     ...  ...
# 5484            2018      600594      11-12     NaN     WHTE   ACTWR   49
# 5485            2018      600594      11-12     NaN      EDS   ACTWR   13
# 5486            2018      600594      11-12     NaN      AIG   ACTWR   18
# 5487            2018      600594      11-12     NaN      ALL     AWA   14
# 5488            2018      600594      11-12     NaN      ALL     MCR   14
#
#      total_pct                     school_name
# 0         88.3         Ardrey Kell High School
# 1         89.6         Ardrey Kell High School
# 2         87.3         Ardrey Kell High School
# 3         94.5         Ardrey Kell High School
# 4         75.6         Ardrey Kell High School
# ...        ...                             ...
# 5484      81.6  Merancas Middle College @ CPCC
# 5485      76.9  Merancas Middle College @ CPCC
# 5486      83.3  Merancas Middle College @ CPCC
# 5487      85.7  Merancas Middle College @ CPCC
# 5488        95  Merancas Middle College @ CPCC
#
# [5489 rows x 9 columns]

# %%
six = pd.read_excel('accdrilldwn1616_4pandas.xlsx')
six.head()
# Out:
#              District Name School Code              School Name SBE District  \
# 0  State of North Carolina          NC  State of North Carolina          NaN
# 1  State of North Carolina          NC  State of North Carolina          NaN
# 2  State of North Carolina          NC  State of North Carolina          NaN
# 3  State of North Carolina          NC  State of North Carolina          NaN
# 4  State of North Carolina          NC  State of North Carolina          NaN
#
#                 Subject Standard (CCR - Level 4 & 5, GLP - Level 3 & Above)  \
# 0  All EOG/EOC Subjects                           College and Career Ready
# 1      All EOC Subjects                           College and Career Ready
# 2           EOC Biology                           College and Career Ready
# 3         EOC English 2                           College and Career Ready
# 4            EOC Math I                           College and Career Ready
#
#   All Students Female  Male American Indian  ... American Indian.1 Asian.1  \
# 0         49.2   51.0  47.6            33.4  ...             24464   64469
# 1         50.9   54.0  48.0            33.6  ...              4598   12697
# 2         47.5   48.5  46.5            33.0  ...              1435    3592
# 3         50.1   56.0  44.4            30.9  ...              1464    3542
# 4         54.1   56.6  51.8            36.5  ...              1699    5563
#
#   Black.1 Hispanic.1 Two or More Races.1  White.1   EDS.1  LEP.1   SWD.1  \
# 0  509546     342683               83948   998834  995415  95195  255617
# 1   96147      57565               14718   200303  170107  13634   42229
# 2   29523      16915                4258    58641   50089   3627   12962
# 3   31119      17970                4508    61362   54188   4153   13851
# 4   35505      22680                5952    80300   65830   5854   15416
#
#     AIG.1
# 0  305064
# 1   76138
# 2   19977
# 3   20321
# 4   35840
#
# [5 rows x 32 columns]

# %%
six.columns
# Out:
# Index(['District Name', 'School Code', 'School Name', 'SBE District',
#        'Subject', 'Standard (CCR - Level 4 & 5, GLP - Level 3 & Above)',
#        'All Students', 'Female', ' Male', 'American Indian', 'Asian', 'Black',
#        'Hispanic', 'Two or More Races', ' White', 'EDS', 'LEP', 'SWD', 'AIG',
#        'All Students.1', 'Female.1', ' Male.1', 'American Indian.1', 'Asian.1',
#        'Black.1', 'Hispanic.1', 'Two or More Races.1', ' White.1', 'EDS.1',
#        'LEP.1', 'SWD.1', 'AIG.1'],
#       dtype='object')

# %%
final_2018.columns
# Out:
# Index(['reporting_year', 'school_code', 'grade_span', 'title_1', 'subgroup',
#        'subject', 'den', 'total_pct', 'school_name'],
#       dtype='object')

# %%
len(six)
# Out:
# 85766

# %%
six_f = six.loc[six['School Code'].isin(ids)].copy()

# %%
six_r = six_f.rename(columns={'School Code':'school_code', 'School Name':'school_name', 
       'Subject':'subject', 'All Students':'ALL', 'Female':'FEM', ' Male':'MALE', 'American Indian':'AMIN', 'Asian':'ASIA', 'Black':'BLCK',
       'Hispanic':'HISP', 'Two or More Races':'MULT', ' White':'WHTE', 'LEP':'ELS',
       'All Students.1':'ALL.1', 'Female.1':'FEM.1', ' Male.1':'MALE.1', 'American Indian.1':'AMIN.1', 'Asian.1':'ASIA.1', 'Black.1':'BLCK.1',
       'Hispanic.1':'HISP.1', 'Two or More Races.1':'MULT.1', ' White.1':'WHTE.1', 'LEP.1':'ELS.1',})

# %%
six_r['reporting_year'] = 2016
six_r['subject'] = six_r['subject'] + six_r['Standard (CCR - Level 4 & 5, GLP - Level 3 & Above)']
six_r = six_r[['reporting_year', 'school_code',  'subject', 'ALL',
       'FEM', 'MALE', 'AMIN', 'ASIA', 'BLCK', 'HISP', 'MULT', 'WHTE', 'EDS',
       'ELS', 'SWD', 'AIG', 'ALL.1', 'FEM.1', 'MALE.1', 'AMIN.1', 'ASIA.1',
       'BLCK.1', 'HISP.1', 'MULT.1', 'WHTE.1', 'EDS.1', 'ELS.1', 'SWD.1',
       'AIG.1']]

# %%
melted_6 = pd.melt(six_r, id_vars=['reporting_year', 'school_code', 'subject','ALL.1', 'FEM.1', 'MALE.1', 'AMIN.1', 'ASIA.1', 'BLCK.1',
       'HISP.1', 'MULT.1', 'WHTE.1', 'EDS.1', 'ELS.1', 'SWD.1', 'AIG.1'], value_vars=['ALL', 'FEM', 'MALE',
       'AMIN', 'ASIA', 'BLCK', 'HISP', 'MULT', 'WHTE', 'EDS', 'ELS', 'SWD',
       'AIG',], var_name = 'subgroup', value_name = 'total_pct')

# %%
melted_6 = pd.melt(melted_6, id_vars=['reporting_year', 'school_code', 'subject', 'subgroup', 'total_pct'], value_vars=['ALL.1', 'FEM.1', 'MALE.1',
       'AMIN.1', 'ASIA.1', 'BLCK.1', 'HISP.1', 'MULT.1', 'WHTE.1', 'EDS.1', 'ELS.1', 'SWD.1', 'AIG.1'], var_name = 'subgroup2', value_name='den')

# %%
school_6 = melted_6.merge(target_schools, on = 'school_code', how='left')
final_2016 = school_6.replace(regex =r'^[<>]', value='').replace(regex =r'^[*]', value='0')
final_2016
# Out:
#         reporting_year school_code  \
# 0                 2017      600302
# 1                 2017      600302
# 2                 2017      600302
# 3                 2017      600302
# 4                 2017      600302
# ...                ...         ...
# 101226            2017      600592
# 101227            2017      600592
# 101228            2017      600592
# 101229            2017      600592
# 101230            2017      600592
#
#                                                 subject subgroup total_pct  \
# 0          All EOG/EOC SubjectsCollege and Career Ready      ALL      86.7
# 1              All EOC SubjectsCollege and Career Ready      ALL      86.7
# 2                   EOC BiologyCollege and Career Ready      ALL      88.6
# 3                 EOC English 2College and Career Ready      ALL      85.0
# 4                    EOC Math ICollege and Career Ready      ALL      86.5
# ...                                                 ...      ...       ...
# 101226           The ACT - ScienceMet The ACT Benchmark      AIG         0
# 101227           The ACT - WritingMet The ACT Benchmark      AIG         0
# 101228  The ACT - All SubtestsPercent of Benchmarks Met      AIG      44.4
# 101229                Math Course RigorPassing Math III      AIG        95
# 101230         ACT WorkKeysSilver or Better Certificate      AIG         0
#
#        subgroup2   den                     school_name
# 0          ALL.1  2406         Ardrey Kell High School
# 1          ALL.1  2406         Ardrey Kell High School
# 2          ALL.1   795         Ardrey Kell High School
# 3          ALL.1   835         Ardrey Kell High School
# 4          ALL.1   776         Ardrey Kell High School
# ...          ...   ...                             ...
# 101226     AIG.1    10  Julius L. Chambers High School
# 101227     AIG.1    10  Julius L. Chambers High School
# 101228     AIG.1    45  Julius L. Chambers High School
# 101229     AIG.1    14  Julius L. Chambers High School
# 101230     AIG.1    10  Julius L. Chambers High School
#
# [101231 rows x 8 columns]

# %%
six = pd.read_excel('accdrilldwn1516_4pandas.xlsx')
six_f = six.loc[six['School Code'].isin(ids)].copy()
six_r = six_f.rename(columns={'School Code':'school_code', 'School Name':'school_name', 
       'Subject':'subject', 'All Students':'ALL', 'Female':'FEM', ' Male':'MALE', 'American Indian':'AMIN', 'Asian':'ASIA', 'Black':'BLCK',
       'Hispanic':'HISP', 'Two or More Races':'MULT', ' White':'WHTE', 'LEP':'ELS',
       'All Students.1':'ALL.1', 'Female.1':'FEM.1', ' Male.1':'MALE.1', 'American Indian.1':'AMIN.1', 'Asian.1':'ASIA.1', 'Black.1':'BLCK.1',
       'Hispanic.1':'HISP.1', 'Two or More Races.1':'MULT.1', ' White.1':'WHTE.1', 'LEP.1':'ELS.1',})
six_r['reporting_year'] = 2016
six_r['subject'] = six_r['subject'] + six_r['Standard (CCR - Level 4 & 5, GLP - Level 3 & Above)']
six_r = six_r[['reporting_year', 'school_code',  'subject', 'ALL',
       'FEM', 'MALE', 'AMIN', 'ASIA', 'BLCK', 'HISP', 'MULT', 'WHTE', 'EDS',
       'ELS', 'SWD', 'AIG', 'ALL.1', 'FEM.1', 'MALE.1', 'AMIN.1', 'ASIA.1',
       'BLCK.1', 'HISP.1', 'MULT.1', 'WHTE.1', 'EDS.1', 'ELS.1', 'SWD.1',
       'AIG.1']]
melted_6 = pd.melt(six_r, id_vars=['reporting_year', 'school_code', 'subject','ALL.1', 'FEM.1', 'MALE.1', 'AMIN.1', 'ASIA.1', 'BLCK.1',
       'HISP.1', 'MULT.1', 'WHTE.1', 'EDS.1', 'ELS.1', 'SWD.1', 'AIG.1'], value_vars=['ALL', 'FEM', 'MALE',
       'AMIN', 'ASIA', 'BLCK', 'HISP', 'MULT', 'WHTE', 'EDS', 'ELS', 'SWD',
       'AIG',], var_name = 'subgroup', value_name = 'total_pct')
melted_6 = pd.melt(melted_6, id_vars=['reporting_year', 'school_code', 'subject', 'subgroup', 'total_pct'], value_vars=['ALL.1', 'FEM.1', 'MALE.1',
       'AMIN.1', 'ASIA.1', 'BLCK.1', 'HISP.1', 'MULT.1', 'WHTE.1', 'EDS.1', 'ELS.1', 'SWD.1', 'AIG.1'], var_name = 'subgroup2', value_name='den')
school_6 = melted_6.merge(target_schools, on = 'school_code', how='left')
final_2016 = school_6.replace(regex =r'^[<>]', value='').replace(regex =r'^[*]', value='0')
final_2016
# Out:
#        reporting_year school_code  \
# 0                2016      600302
# 1                2016      600302
# 2                2016      600302
# 3                2016      600302
# 4                2016      600302
# ...               ...         ...
# 95311            2016      600592
# 95312            2016      600592
# 95313            2016      600592
# 95314            2016      600592
# 95315            2016      600592
#
#                                                subject subgroup total_pct  \
# 0         All EOG/EOC SubjectsCollege and Career Ready      ALL      85.1
# 1             All EOC SubjectsCollege and Career Ready      ALL      85.1
# 2                  EOC BiologyCollege and Career Ready      ALL      87.5
# 3                EOC English 2College and Career Ready      ALL      82.4
# 4                   EOC Math ICollege and Career Ready      ALL      85.0
# ...                                                ...      ...       ...
# 95311           The ACT - ScienceMet The ACT Benchmark      AIG      14.3
# 95312           The ACT - WritingMet The ACT Benchmark      AIG      42.9
# 95313  The ACT - All SubtestsPercent of Benchmarks Met      AIG      25.7
# 95314                Math Course RigorPassing Math III      AIG        95
# 95315         ACT WorkKeysSilver or Better Certificate      AIG         0
#
#       subgroup2   den                     school_name
# 0         ALL.1  2384         Ardrey Kell High School
# 1         ALL.1  2384         Ardrey Kell High School
# 2         ALL.1   843         Ardrey Kell High School
# 3         ALL.1   740         Ardrey Kell High School
# 4         ALL.1   801         Ardrey Kell High School
# ...         ...   ...                             ...
# 95311     AIG.1    14  Julius L. Chambers High School
# 95312     AIG.1    14  Julius L. Chambers High School
# 95313     AIG.1    70  Julius L. Chambers High School
# 95314     AIG.1    14  Julius L. Chambers High School
# 95315     AIG.1    10  Julius L. Chambers High School
#
# [95316 rows x 8 columns]

# %%
final_2016['subject'].unique()
# Out:
# array(['All EOG/EOC SubjectsCollege and Career Ready',
#        'All EOC SubjectsCollege and Career Ready',
#        'EOC BiologyCollege and Career Ready',
#        'EOC English 2College and Career Ready',
#        'EOC Math ICollege and Career Ready',
#        'All EOG/EOC SubjectsGrade Level Proficient',
#        'All EOC SubjectsGrade Level Proficient',
#        'EOC BiologyGrade Level Proficient',
#        'EOC English 2Grade Level Proficient',
#        'EOC Math IGrade Level Proficient',
#        'Graduation RateStandard (4 Year)',
#        'Graduation RateExtended (5 year)',
#        'The ACT - Composite ScoreMet UNC Minimum',
#        'The ACT - EnglishMet The ACT Benchmark',
#        'The ACT - ReadingMet The ACT Benchmark',
#        'The ACT - MathMet The ACT Benchmark',
#        'The ACT - ScienceMet The ACT Benchmark',
#        'The ACT - WritingMet The ACT Benchmark',
#        'The ACT - All SubtestsPercent of Benchmarks Met',
#        'Math Course RigorPassing Math III',
#        'ACT WorkKeysSilver or Better Certificate',
#        'All EOG SubjectsCollege and Career Ready',
#        'EOG Grade 3College and Career Ready',
#        'EOG Grade 4College and Career Ready',
#        'EOG Grade 5College and Career Ready',
#        'EOG Grade 6College and Career Ready',
#        'EOG Grade 7College and Career Ready',
#        'EOG Grade 8College and Career Ready',
#        'EOG Reading Grades 3-8College and Career Ready',
#        'EOG Reading Grade 3College and Career Ready',
#        'EOG Reading Grade 4College and Career Ready',
#        'EOG Reading Grade 5College and Career Ready',
#        'EOG Reading Grade 6College and Career Ready',
#        'EOG Reading Grade 7College and Career Ready',
#        'EOG Reading Grade 8College and Career Ready',
#        'EOG Math Grades 3-8College and Career Ready',
#        'EOG Math Grade 3College and Career Ready',
#        'EOG Math Grade 4College and Career Ready',
#        'EOG Math Grade 5College and Career Ready',
#        'EOG Math Grade 6College and Career Ready',
#        'EOG Math Grade 7College and Career Ready',
#        'EOG Math Grade 8College and Career Ready',
#        'EOG Science Grades 5&8College and Career Ready',
#        'EOG Science Grade 5College and Career Ready',
#        'EOG Science Grade 8College and Career Ready',
#        'All EOG SubjectsGrade Level Proficient',
#        'EOG Grade 3Grade Level Proficient',
#        'EOG Grade 4Grade Level Proficient',
#        'EOG Grade 5Grade Level Proficient',
#        'EOG Grade 6Grade Level Proficient',
#        'EOG Grade 7Grade Level Proficient',
#        'EOG Grade 8Grade Level Proficient',
#        'EOG Reading Grades 3-8Grade Level Proficient',
#        'EOG Reading Grade 3Grade Level Proficient',
#        'EOG Reading Grade 4Grade Level Proficient',
#        'EOG Reading Grade 5Grade Level Proficient',
#        'EOG Reading Grade 6Grade Level Proficient',
#        'EOG Reading Grade 7Grade Level Proficient',
#        'EOG Reading Grade 8Grade Level Proficient',
#        'EOG Math Grades 3-8Grade Level Proficient',
#        'EOG Math Grade 3Grade Level Proficient',
#        'EOG Math Grade 4Grade Level Proficient',
#        'EOG Math Grade 5Grade Level Proficient',
#        'EOG Math Grade 6Grade Level Proficient',
#        'EOG Math Grade 7Grade Level Proficient',
#        'EOG Math Grade 8Grade Level Proficient',
#        'EOG Science Grades 5&8Grade Level Proficient',
#        'EOG Science Grade 5Grade Level Proficient',
#        'EOG Science Grade 8Grade Level Proficient'], dtype=object)

# %%
metrics = { 'CGRE': 'Graduation RateExtended (5 year)',
           'CGRS': 'Graduation RateExtended (5 year)',
           'ACA': 'ACT Workkeys',
           'ACT WorkKeysSilver or Better Certificate': 'ACT Workkeys',
           'The ACT - Composite ScoreMet UNC Minimum': 'ACT Composite',
           'ACT': 'ACT Composite'
}

# %%
dfs = [final_2016, final_2017, final_2018, final_2019]
for df in dfs:
    print(len(df['school_code'].unique()))
    print(len(df))
    df.to_csv(f'final{df['reporting_year'].loc[0]}')
# Out:
# 25
# 95316
# 27
# 101231
# 30
# 5489
# 31
# 7980

# %%
mega_df = pd.concat(dfs, ignore_index=True, join='inner')
mega_df['subject'] = mega_df['subject'].map(metrics).fillna(mega_df['subject'])

# %%
mega_df.head()
# Out:
#    reporting_year school_code                                       subject  \
# 0            2016      600302  All EOG/EOC SubjectsCollege and Career Ready
# 1            2016      600302      All EOC SubjectsCollege and Career Ready
# 2            2016      600302           EOC BiologyCollege and Career Ready
# 3            2016      600302         EOC English 2College and Career Ready
# 4            2016      600302            EOC Math ICollege and Career Ready
#
#   subgroup total_pct   den              school_name
# 0      ALL      85.1  2384  Ardrey Kell High School
# 1      ALL      85.1  2384  Ardrey Kell High School
# 2      ALL      87.5   843  Ardrey Kell High School
# 3      ALL      82.4   740  Ardrey Kell High School
# 4      ALL      85.0   801  Ardrey Kell High School

# %%
len(mega_df)
# Out:
# 210016

# %%
mega_df.to_csv('Output\alex_15_19.csv', index=False)
