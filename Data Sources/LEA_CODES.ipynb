# %%
import pandas as pd
import seaborn as sns

# %%
sixteen = pd.read_csv("sixteen_to_sql.csv")
# Out:
# C:\Users\Alexander Saunders\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sixteen.head()
# Out:
#              District Name School Code              School Name SBE District  \
# 0  State of North Carolina          NC  State of North Carolina          NaN
# 1  State of North Carolina          NC  State of North Carolina          NaN
# 2  State of North Carolina          NC  State of North Carolina          NaN
# 3  State of North Carolina          NC  State of North Carolina          NaN
# 4  State of North Carolina          NC  State of North Carolina          NaN
#
#                 Subject Standard (CCR - Level 4 & 5, GLP - Level 3 & Above)  \
# 0  All EOG/EOC Subjects                           College and Career Ready
# 1      All EOC Subjects                           College and Career Ready
# 2           EOC Biology                           College and Career Ready
# 3         EOC English 2                           College and Career Ready
# 4            EOC Math I                           College and Career Ready
#
# ...

# %%
sixteen['District Name'].unique()
# Out:
# array(['State of North Carolina', 'Alamance-Burlington Schools',
#        'Alexander County Schools', 'Alleghany County Schools',
#        'Anson County Schools', 'Ashe County Schools',
#        'Avery County Schools', 'Beaufort County Schools',
#        'Bertie County Schools', 'Bladen County Schools',
#        'Brunswick County Schools', 'Buncombe County Schools',
#        'Asheville City Schools', 'Burke County Schools',
#        'Cabarrus County Schools', 'Kannapolis City Schools',
#        'Caldwell County Schools', 'Camden County Schools',
#        'Carteret County Public Schools', 'Caswell County Schools',
#        'Catawba County Schools', 'Hickory City Schools',
#        'Newton Conover City Schools', 'Chatham County Schools',
#        'Cherokee County Schools', 'Edenton-Chowan Schools',
#        'Clay County Schools', 'Cleveland County Schools',
#        'Columbus County Schools', 'Whiteville City Schools',
#        'Craven County Schools', 'Cumberland County Schools',
# ...

# %%
char_meck = sixteen.loc[sixteen['District Name'] == 'Charlotte-Mecklenburg Schools']

# %%
char_meck.columns
# Out:
# Index(['District Name', 'School Code', 'School Name', 'SBE District',
#        'Subject', 'Standard (CCR - Level 4 & 5, GLP - Level 3 & Above)',
#        'All Students', 'Female', ' Male', 'American Indian', 'Asian', 'Black',
#        'Hispanic', 'Two or More Races', ' White', 'EDS', 'LEP', 'SWD', 'AIG',
#        'All Students.1', 'Female.1', ' Male.1', 'American Indian.1', 'Asian.1',
#        'Black.1', 'Hispanic.1', 'Two or More Races.1', ' White.1', 'EDS.1',
#        'LEP.1', 'SWD.1', 'AIG.1'],
#       dtype='object')

# %%
char_meck['Subject'].unique()
# Out:
# array(['All EOG/EOC Subjects', 'All EOC Subjects', 'EOC Biology',
#        'EOC English 2', 'EOC Math I', 'All EOG Subjects', 'EOG Grade 3',
#        'EOG Grade 4', 'EOG Grade 5', 'EOG Grade 6', 'EOG Grade 7',
#        'EOG Grade 8', 'EOG Reading Grades 3-8', 'EOG Reading Grade 3',
#        'EOG Reading Grade 4', 'EOG Reading Grade 5',
#        'EOG Reading Grade 6', 'EOG Reading Grade 7',
#        'EOG Reading Grade 8', 'EOG Math Grades 3-8', 'EOG Math Grade 3',
#        'EOG Math Grade 4', 'EOG Math Grade 5', 'EOG Math Grade 6',
#        'EOG Math Grade 7', 'EOG Math Grade 8', 'EOG Science Grades 5&8',
#        'EOG Science Grade 5', 'EOG Science Grade 8', 'Graduation Rate',
#        'The ACT - Composite Score', 'The ACT - English',
#        'The ACT - Reading', 'The ACT - Math', 'The ACT - Science',
#        'The ACT - Writing', 'The ACT - All Subtests', 'Math Course Rigor',
#        'ACT WorkKeys'], dtype=object)

# %%
char_meck_high = char_meck.loc[char_meck['Subject']== 'The ACT - Composite Score'][['School Name', 'School Code']].iloc[1:,]

# %%
char_meck_high.to_csv('char_meck_lea.csv')

# %%
charters = sixteen.loc[sixteen['District Name'] == 'Charter Schools']
charters = charters.loc[charters['Subject']== 'The ACT - Composite Score']
charters = charters.loc[charters['SBE District'] == 'Southwest']

# %%
charters
# Out:
#          District Name School Code                        School Name  \
# 78907  Charter Schools      13A000      Carolina International School
# 80664  Charter Schools      36B000  Piedmont Community Charter School
# 80732  Charter Schools      36C000     Mountain Island Charter School
# 81588  Charter Schools      49E000              Pine Lake Preparatory
# 81922  Charter Schools      55A000             Lincoln Charter School
# 82054  Charter Schools      60B000                Sugar Creek Charter
# 82109  Charter Schools      60D000                Lake Norman Charter
# 82233  Charter Schools      60G000     Queen's Grant Community School
# 82301  Charter Schools      60I000       Community School of Davidson
# 82403  Charter Schools      60K000                Charlotte Secondary
# 82745  Charter Schools      60V000         Charlotte Learning Academy
# 84137  Charter Schools      84B000                     Gray Stone Day
# ...
