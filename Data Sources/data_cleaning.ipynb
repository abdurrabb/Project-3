# %%
import pandas as pd

# %%
sixteen = pd.read_csv('accdrilldwn1617.csv')
fourteen = pd.read_csv('acctdrilldwn1415.csv')
# Out:
# C:\Users\Alexander Saunders\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
fifteen = pd.read_csv("accdrilldwn16.csv")
# Out:
# C:\Users\Alexander Saunders\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sixteen.head()
# Out:
#              District Name School Code              School Name SBE District  \
# 0  State of North Carolina          NC  State of North Carolina          NaN
# 1  State of North Carolina          NC  State of North Carolina          NaN
# 2  State of North Carolina          NC  State of North Carolina          NaN
# 3  State of North Carolina          NC  State of North Carolina          NaN
# 4  State of North Carolina          NC  State of North Carolina          NaN
#
#                 Subject Standard (CCR - Level 4 & 5, GLP - Level 3 & Above)  \
# 0  All EOG/EOC Subjects                           College and Career Ready
# 1      All EOC Subjects                           College and Career Ready
# 2           EOC Biology                           College and Career Ready
# 3         EOC English 2                           College and Career Ready
# 4            EOC Math I                           College and Career Ready
#
# ...

# %%
fourteen.head()
# Out:
#              District Name School Code              School Name  SBE District  \
# 0  State of North Carolina          NC  State of North Carolina           NaN
# 1  State of North Carolina          NC  State of North Carolina           NaN
# 2  State of North Carolina          NC  State of North Carolina           NaN
# 3  State of North Carolina          NC  State of North Carolina           NaN
# 4  State of North Carolina          NC  State of North Carolina           NaN
#
#                 Subject Standard (CCR - Level 4 & 5, GLP - Level 3 & Above)  \
# 0  All EOG/EOC Subjects                           College and Career Ready
# 1      All EOC Subjects                           College and Career Ready
# 2           EOC Biology                           College and Career Ready
# 3         EOC English 2                           College and Career Ready
# 4            EOC Math I                           College and Career Ready
#
# ...

# %%
fifteen.head()
# Out:
#              District Name School Code              School Name SBE District  \
# 0  State of North Carolina          NC  State of North Carolina          NaN
# 1  State of North Carolina          NC  State of North Carolina          NaN
# 2  State of North Carolina          NC  State of North Carolina          NaN
# 3  State of North Carolina          NC  State of North Carolina          NaN
# 4  State of North Carolina          NC  State of North Carolina          NaN
#
#                 Subject Standard (CCR - Level 4 & 5, GLP - Level 3 & Above)  \
# 0  All EOG/EOC Subjects                           College and Career Ready
# 1      All EOC Subjects                           College and Career Ready
# 2           EOC Biology                           College and Career Ready
# 3         EOC English 2                           College and Career Ready
# 4            EOC Math I                           College and Career Ready
#
# ...

# %%
fifteen.replace(regex =r'^[<>*]', value='', inplace=True)
fifteen.iloc[:,6:32] = fifteen.iloc[:,6:32].apply(lambda x: pd.to_numeric(x, errors='raise'))

# %%
fifteen.to_csv('fifteen_to_sql.csv', index=False)

# %%
fourteen.replace(regex =r'^[<>*]', value='', inplace=True)
fourteen.iloc[:,6:32] = fourteen.iloc[:,6:32].apply(lambda x: pd.to_numeric(x, errors='raise'))
fourteen.to_csv('fourteen_to_sql.csv', index=False)

# %%
sixteen.replace(regex =r'^[<>*]', value='', inplace=True)
sixteen.iloc[:,6:32] = sixteen.iloc[:,6:32].apply(lambda x: pd.to_numeric(x, errors='raise'))
sixteen.to_csv('sixteen_to_sql.csv', index=False)

# %%
fif_others = pd.read_csv('1516otherindicators.csv')
fif_others.head()
# Out:
#                  District Name School Code  \
# 0      State of North Carolina          NC
# 1  Alamance-Burlington Schools         010
# 2  Alamance-Burlington Schools      010303
# 3  Alamance-Burlington Schools      010304
# 4  Alamance-Burlington Schools      010308
#
#                           School Name           SBE District  \
# 0             State of North Carolina                    NaN
# 1         Alamance-Burlington Schools  Piedmont Triad Region
# 2  Alamance-Burlington Middle College  Piedmont Triad Region
# 3         Alexander Wilson Elementary  Piedmont Triad Region
# 4              Altamahaw Ossipee Elem  Piedmont Triad Region
#
#   EVAAS Growth Status  Percent Participation ACT Percent ACT WorkKeys Percent  \
# 0                 NaN                   94.9        59.9                 73.5
# 1                 NaN                   92.0        51.3                 69.1
# 2                 Met                  100.0        82.8                    *
# ...

# %%
fif_others.replace(regex =r'^[<>*]', value='', inplace=True)
fif_others.iloc[:,6:11] = fif_others.iloc[:,6:11].apply(lambda x: pd.to_numeric(x, errors='raise'))

# %%
fif_others.to_csv('1516other_tosql.csv', index=False)

# %%
six_others = pd.read_csv('1617otherindicators.csv')
six_others.replace(regex =r'^[<>*]', value='', inplace=True)
six_others.iloc[:,6:11] = fif_others.iloc[:,6:11].apply(lambda x: pd.to_numeric(x, errors='raise'))
six_others.dropna(how='all', axis=1,inplace=True)
six_others.head()
# Out:
#                  District Name School Code  \
# 0      State of North Carolina          NC
# 1  Alamance-Burlington Schools         010
# 2  Alamance-Burlington Schools      010303
# 3  Alamance-Burlington Schools      010304
# 4  Alamance-Burlington Schools      010308
#
#                                 School Name    SBE District  \
# 0                   State of North Carolina             NaN
# 1               Alamance-Burlington Schools  Piedmont-Triad
# 2  Alamance-Burlington Middle/Early College  Piedmont-Triad
# 3               Alexander Wilson Elementary  Piedmont-Triad
# 4                    Altamahaw Ossipee Elem  Piedmont-Triad
#
#   EVAAS Growth Status  EVAAS Growth Index  Percent Participation Targets Met  \
# 0                 NaN                 NaN                               59.9
# 1                 NaN                 NaN                               51.3
# 2                 Met                0.29                               82.8
# ...

# %%
six_others.to_csv('1617other_tosql.csv', index=False)

# %%
six_others.head()
# Out:
#                  District Name School Code  \
# 0      State of North Carolina          NC
# 1  Alamance-Burlington Schools         010
# 2  Alamance-Burlington Schools      010303
# 3  Alamance-Burlington Schools      010304
# 4  Alamance-Burlington Schools      010308
#
#                                 School Name    SBE District  \
# 0                   State of North Carolina             NaN
# 1               Alamance-Burlington Schools  Piedmont-Triad
# 2  Alamance-Burlington Middle/Early College  Piedmont-Triad
# 3               Alexander Wilson Elementary  Piedmont-Triad
# 4                    Altamahaw Ossipee Elem  Piedmont-Triad
#
#   EVAAS Growth Status  EVAAS Growth Index  Percent Participation Targets Met  \
# 0                 NaN                 NaN                               59.9
# 1                 NaN                 NaN                               51.3
# 2                 Met                0.29                               82.8
# ...

# %%
absenteeism = pd.read_csv("absenteeismreport.csv")

# %%
absenteeism.drop_duplicates()
absenteeism.replace(regex =r'^[<>*]', value='', inplace=True)

# %%
absenteeism = pd.read_csv("absenteeismreport.csv")
absenteeism.drop_duplicates()
absenteeism.replace(regex =r'^[<>*]', value='', inplace=True)
absenteeism.to_csv('absentee_to_sql.csv', index=False)
