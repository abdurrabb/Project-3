# %%
import pymongo
dbuserpw = "billygoat"
user = "user05"

# %%
client = pymongo.MongoClient(f"mongodb+srv://{user}:{dbuserpw}@cluster0.husnw.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test_db

# %%
counties = db.counties

# %%
counties
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-01.husnw.mongodb.net:27017', 'cluster0-shard-00-02.husnw.mongodb.net:27017', 'cluster0-shard-00-00.husnw.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-uhv186-shard-0', ssl=True), 'test_db'), 'counties')

# %%
counties.insert_one(
    {
        "county": "mecklenberg",
        "thing1": "Yup",
        "thing2": "Nope"
    }
)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-11-b196f883d99f> in <module>
# ----> 1 counties.insert_one(
#       2     {
#       3         "county": "mecklenberg",
#       4         "thing1": "Yup",
#       5         "thing2": "Nope"
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     703         write_concern = self._write_concern_for(session)
#     704         return InsertOneResult(
# --> 705             self._insert(document,
#     706                          write_concern=write_concern,
#     707                          bypass_doc_val=bypass_document_validation,
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     618         """Internal insert helper."""
# ...

# %%
results = counties.find()

# %%
for doc in results:
    print(doc)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-22-715243c415d0> in <module>
# ----> 1 for doc in results:
#       2     print(doc)
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1236         if self.__empty:
#    1237             raise StopIteration
# -> 1238         if len(self.__data) or self._refresh():
#    1239             if self.__manipulate:
#    1240                 _db = self.__collection.database
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1128
#    1129         if not self.__session:
# -> 1130             self.__session = self.__collection.database.client._ensure_session()
#    1131
#    1132         if self.__id is None:  # Query
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _ensure_session(self, session)
# ...
